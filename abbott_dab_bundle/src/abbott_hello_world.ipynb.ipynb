# %%
print("Abbott bundle testing")

# %%
# %sql
CREATE TABLE users.sithara_vanmerimeethal.my_external_table (
  id      BIGINT,
  name    STRING,
  created DATE
)
USING DELTA;

# %%
from databricks.sdk import WorkspaceClient
w = WorkspaceClient()
sp = w.service_principals.create(display_name="sithara.vanmerimeethal-my-sp")
print(sp.id)
